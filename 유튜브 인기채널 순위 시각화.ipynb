# %%
#목표 : 유튜브 인기 채널 및 영상 분석
#문제 정의 : Kaggle에서 유튜브 순위 데이터를 가져와 EDA를 통해 인기 채널을 순위를 시각화한다. 
#결론

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# !apt -qq -y install fonts-nanum > /dev/null
 
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
 
fontpath = 'C:/Users/hongm/Downloads/맑은고딕/malgun.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()
 
# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'
 
# Colab 의 한글 폰트 설정
# plt.rc('font', family='NanumBarunGothic')

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
 
# %config InlineBackend.figure_format = 'retina'

 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
font_path = 'C:/Users/hongm/Downloads/맑은고딕/malgun.ttf'
fontprop = fm.FontProperties(fname=font_path, size=18)

# %%
plt.figure(figsize=(5,5))
plt.plot([0,1], [0,1], label='한글테스트용')
plt.legend()
plt.show()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#에러발생 CSV 한글이 폰트가 계속 계짐 ... 모든 방법 총동원

KRvideo = pd.read_csv("C:/Users/hongm/Downloads/archive/KRvideos2.csv", engine="python", error_bad_lines= False,)
KRvideo
# Out:
#           video_id trending_date  \
# 0      RxGQe4EeEpA      17.14.11
# 1      hH7wVE8OlQ0      17.14.11
# 2      9V8bnWUmE9U      17.14.11
# 3      0_8py-t5R80      17.14.11
# 4      bk55RbxiQdI      17.14.11
# ...            ...           ...
# 32360  pj6YBBrO1sQ      18.14.06
# 32361  _Ne9ER-jr20      18.14.06
# 32362  xuOQq_fzEjk      18.14.06
# 32363  uXvjxeg08eQ      18.14.06
# 32364  C-bLqIftDY4      18.14.06
#
#                                                    title  \
# 0                                醫뗭븘 by 誘쇱꽌_?ㅼ쥌??醫뗫땲 ?듦?
# 1                            JSA 洹�??遺곹븳援?珥앷꺽 遺�??Edward
# 2                     ?섎ぐ?쇳뙣諛�由??대룞???곸긽 2??(鍮쇰뭡濡쒕뜲?대쾭??
# 3                    ?뗡뀿?녲뀱?솽꼪?■넧 異쒓뎅 ?꾩옣, ?볦튂硫??덈릺???λ㈃
# 4                       源�?κ껴?� 臾쇰윭媛붾떎 MBC ?몄“ ?섑샇?� ?덈Ъ
# ...                                                  ...
# 32360     ?λえ??媛�寃뚰븳?ㅺ퀬 1?듬쭔 ?щ씪???꾨궡 ?ъ씠?ㅼ뭅???댁뒋?몃옒而?24
# 32361           ?щ윭遺? ?뚯쫰媛� ?대젃寃??꾪뿕?⑸땲??!!?쒌뀥 _[?댁뒋?붾윭]
# ...

# %%
# -*- coding: utf-8 -*-
path = 'd:/test.txt'
with open(path, 'rb') as f:
    buf  = f.read()
    print(buf)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-86-f2444e5579c0> in <module>
#       1 # -*- coding: utf-8 -*-
#       2 path = 'd:/test.txt'
# ----> 3 with open(path, 'rb') as f:
#       4     buf  = f.read()
#       5     print(buf)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'd:/test.txt'

# %%
#row,column 수 파악하기
KRvideo.shape
# Out:
# (34567, 16)

# %%
KRvideo.isnull().sum()
# Out:
# video_id                     0
# trending_date                0
# title                        0
# channel_title                0
# category_id                  0
# publish_time                 0
# tags                         0
# views                        0
# likes                        0
# dislikes                     0
# comment_count                0
# thumbnail_link               0
# comments_disabled            0
# ratings_disabled             0
# video_error_or_removed       0
# description               3163
# dtype: int64

# %%
#데이터 정리
df = KRvideo[['title','channel_title']]
df
# Out:
#                                                    title         channel_title
# 0                              醫뗭븘 by 誘쇱꽌_�쑄醫낆떊_醫뗫땲 �떟媛�            �씪�뫖留덉퐫由ъ븘
# 1                                JSA 洹��닚 遺곹븳援� 珥앷꺽 遺��긽                Edward
# 2              �굹紐곕씪�뙣諛�由� �슫�룞�솕 �쁺�긽 2�깂 (鍮쇰뭡濡쒕뜲�씠踰꾩졏)      �굹紐곕씪�뙣諛�由� �빂�눥
# 3           �꼱�뀿�꼩�뀱�녅�꼪�뀫�넧 異쒓뎅 �쁽�옣, �넃移섎㈃ �븞�릺�뒗 �옣硫�              誘몃뵒�뼱紐쎄뎄
# 4                  源��옣寃몄�� 臾쇰윭媛붾떎 MBC �끂議� �솚�샇��� �늿臾�                NocutV
# ...                                                  ...                   ...
# 34562        �옣紐⑤떂 媛�寃뚰븳�떎怨� 1�뼲留� �떖�씪�뒗 �븘�궡 �궗�씠�떎移댄넚            �씠�뒋�듃�옒而�
# 34563  �뿬�윭遺�~ �젋利덇�� �씠�젃寃� �쐞�뿕�빀�땲�떎!!!�뀥�뀥 _[�씠�뒋...  �씠�뒋�뀛�윭 issueTeller
# 34564                          2018�뀈 6�썡 13�씪 �븘移� �돱�뒪          News Express
# 34565           �썙�꼫�썝 �썐�쓬 李멸린 �쁺�긽 �썙�꼫�썝 GO X-con.ver                  �썝�뵆
# 34566  [踰뺣쪣�뒪�떂�쓽 利됰Ц利됱꽕 �젣 1398�쉶] �떆�룞�깮�쓽 �븘�씠瑜� �...      踰뺣쪣�뒪�떂�쓽 利됰Ц利됱꽕
#
# ...
